# %% [markdown]
# ## test import und plotten Lidar Daten mit laspy nach
# #### https://geospatialawarenesshub.com/blog/essentials-of-lidar-point-cloud-processing-using-python/

# %%
import laspy
import numpy as np
import matplotlib.pyplot as plt

# %%
inFile = laspy.read("laz2014_609225.laz")

# %%
# %matplotlib inline
fig = plt.figure(figsize=[20, 5])
ax = plt.axes(projection='3d')
sc = ax.scatter(inFile.x, inFile.y, inFile.z, c=inFile.z ,s=0.1, marker='o', cmap="Spectral")
plt.colorbar(sc)
plt.show()

# %%
#Header format
    
inFile.header.point_count
# Out:
# 11518442

# %%
list(inFile.header.point_format.dimension_names)
# Out:
# ['X',
#  'Y',
#  'Z',
#  'intensity',
#  'return_number',
#  'number_of_returns',
#  'scan_direction_flag',
#  'edge_of_flight_line',
#  'classification',
#  'synthetic',
#  'key_point',
#  'withheld',
#  'scan_angle_rank',
#  'user_data',
#  'point_source_id',
#  'gps_time']

# %%
import pdal
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9196/3968280360.py in <module>
# ----> 1 import pdal
#
# ~\Anaconda3\lib\site-packages\pdal\__init__.py in <module>
#       2 __all__ = ["Pipeline", "Stage", "Reader", "Filter", "Writer", "dimensions", "info"]
#       3
# ----> 4 from . import libpdalpython
#       5 from .drivers import inject_pdal_drivers
#       6 from .pipeline import Filter, Pipeline, Reader, Stage, Writer
#
# ImportError: DLL load failed: Das angegebene Modul wurde nicht gefunden.

# %%
import pylas
